# %% [markdown]
# ### Limited Resolution environments:
#
# - if project supports a more limited set of platforms or Python versions, you can constrain the set of solved platforms via the environments setting

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/limited-resolution.png')
new_image = img.resize((280, 160))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=280x160>
