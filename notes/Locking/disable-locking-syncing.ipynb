# %% [markdown]
# ### Disable locking and syncing of project environment:
#
# Options:
# 1. if we do not want uv to manage the project environment and disable automatic locking and syncing of the project, in ```pyproject.toml``` file use
#
#     ```[tool.uv]```
#
#     ```managed = false```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/locking_disable.png')
new_image = img.resize((190, 130))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=190x130>

# %% [markdown]
# 2. ```uv run --locked```
