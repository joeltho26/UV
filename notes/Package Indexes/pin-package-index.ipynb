# %% [markdown]
# ### Pinning a package to an index:
#
# - to ensure that torch is always installed from the pytorch index

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/package1.png')
new_image = img.resize((350, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x120>
