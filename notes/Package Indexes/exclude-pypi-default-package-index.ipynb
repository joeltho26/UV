# %% [markdown]
# ### To exclude pypi as default package indexes:
#
# - To exclude PyPI from the list of indexes, set ```default = true``` in ```pyproject.toml``` file
# - or use ```--default-index``` in command-line

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/package.png')
new_image = img.resize((350, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x80>
