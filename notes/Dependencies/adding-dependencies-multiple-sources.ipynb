# %% [markdown]
# #### Multiple sources (index):

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/index_mul.png')
new_image = img.resize((550, 420))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=550x420>
