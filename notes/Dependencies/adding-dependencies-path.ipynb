# %% [markdown]
# ### Install dependencies via path:
#
# ```uv add /example/foo-0.1.0-py3-none-any.whl```
#
# ```uv add ./foo-0.1.0-py3-none-any.whl``` (relative path)
#
# ```uv add ~/projects/bar/```
#
#
# - provide the path of a wheel (.whl)
# - provide the path of source distribution (.tar, .gz, .zip)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/url.png')
new_image = img.resize((640, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x150>

# %% [markdown]
# - Editable installation:
#     - An editable installation may be requested for project directories
#
#         ```uv add --editable ../projects/bar/```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/editable.png')
new_image = img.resize((450, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x150>
