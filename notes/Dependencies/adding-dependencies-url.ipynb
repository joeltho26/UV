# %% [markdown]
# ### Install dependencies via URL:
#
# ```uv add "https://files.pythonhosted.org/packages/5c/2d/3da5bdf4408b8b2800061c339f240c1802f2e82d55e50bd39c5a881f47f0/httpx-0.27.0.tar.gz"```
#
# - can be manually added or edited in the pyproject.toml
# - ```subdirectory``` can be specified if the source distribution isn't in the archive root

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/url.png')
new_image = img.resize((610, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=610x150>
