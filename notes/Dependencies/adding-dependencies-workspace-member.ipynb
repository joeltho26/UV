# %% [markdown]
# ### Install dependencies for workspace members:
#
# -  declare a dependency on a workspace member
# - Workspace member:
#     - inspired by the Cargo concept (RUST package installer/manager) of the same name, a workspace is "a collection of one or more packages, called workspace members, that are managed together

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/workspace.png')
new_image = img.resize((250, 230))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x230>
