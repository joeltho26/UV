# %% [markdown]
# ### Install optional dependencies:
#
# ```uv add httpx --optional network```
#
# - make some features optional to reduce the default dependency tree

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/optional.png')
new_image = img.resize((250, 360))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x360>

# %% [markdown]
# - optional dependencies can be applied to dependency sources eg: ```index```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/optional2.png')
new_image = img.resize((410, 510))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=410x510>
