# %% [markdown]
# ### Create a python project packaged application using uv:
#
# ```uv init --package example-pkg```

# %%
"""
example-pkg
├── .python-version
├── README.md
├── pyproject.toml
└── src
    └── example_pkg
        └── __init__.py
"""
# Out:
# '\nexample-pkg\n├── .python-version\n├── README.md\n├── pyproject.toml\n└── src\n    └── example_pkg\n        └── __init__.py\n'

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/complete.png')
new_image = img.resize((370, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=370x340>

# %% [markdown]
# Note:
# - ```--build-backend```
#     - can be used to request and alternative build system

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/run.png')
new_image = img.resize((370, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=370x340>

# %% [markdown]
# - the packaged application can be executed by the below commands,
#
#     ```cd example-pkg```
#
#     ```uv run example-pkg```

# %% [markdown]
# - we can use different build systems like
#     - hatchling
#     - uv_build
#     - flit-core
#     - pdm-backend
#     - setuptools
#     - maturin
#     - scikit-build-core
