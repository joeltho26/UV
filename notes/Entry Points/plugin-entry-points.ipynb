# %% [markdown]
# ### Plugins entry points:
#
# Entry points:
# - The entry point is the first instruction or function executed in a software package
#
# to register the ```example-plugin-a``` package as a plugin for ```example```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/plugins.png')
new_image = img.resize((350, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x90>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/plugins2.png')
new_image = img.resize((390, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x120>
