# %% [markdown]
# ### Command line interface:
#
# - declare a command ```uv run hello``` to invoke the hellow function in the example project/module

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/cli.png')
new_image = img.resize((220, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x90>
