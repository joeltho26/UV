# %% [markdown]
# ### GUI via scripts UV:
#
# ```uv run example.pyw```

# %%
from tkinter import Tk, ttk

root = Tk()
root.title("uv")
frm = ttk.Frame(root, padding=10)
frm.grid()
ttk.Label(frm, text="Hello World").grid(column=0, row=0)
root.mainloop()

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gui.png')
new_image = img.resize((260, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=260x100>

# %% [markdown]
# - to make a cli exhibit GUI:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gui2.png')
new_image = img.resize((210, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=210x100>
