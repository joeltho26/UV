# %% [markdown]
# ### Date specific distribution consideration:
#
# -  ```uv``` supports an ```exclude-newer``` field in the ```tool.uv``` section of inline script metadata to limit ```uv``` to only considering distributions released before a specific date

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/date.png')
new_image = img.resize((380, 290))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x290>
